# %%
import hvplot.pandas
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

weather_data_df = pd.read_csv("weather_data/average_temp_by_state.csv")

weather_data_df
# Out:
#        Unnamed: 0  month  year          state  average_temp  \
# 0               0      1  1950        Alabama          53.8
# 1               1      1  1950        Arizona          39.6
# 2               2      1  1950       Arkansas          45.6
# 3               3      1  1950     California          39.4
# 4               4      1  1950       Colorado          25.2
# ...           ...    ...   ...            ...           ...
# 41851       41851      8  2022       Virginia          75.9
# 41852       41852      8  2022     Washington          68.9
# 41853       41853      8  2022  West Virginia          72.4
# 41854       41854      8  2022      Wisconsin          68.3
# 41855       41855      8  2022        Wyoming          68.1
#
#        monthly_mean_from_1901_to_2000  centroid_lon  centroid_lat
# 0                                45.9    -86.828372     32.789832
# 1                                41.1   -111.664418     34.293110
# ...

# %%
# Cleaning up the dataframe and sortin the data

filtered_weather_df = weather_data_df

filtered_weather_df = filtered_weather_df.loc[(filtered_weather_df["year"] >= 2016) & (filtered_weather_df["year"] <= 2021)]

filtered_weather_df = filtered_weather_df.loc[(filtered_weather_df["state"] == "Kansas")]

filtered_weather_df = filtered_weather_df.drop(columns=["Unnamed: 0","monthly_mean_from_1901_to_2000","centroid_lon","centroid_lat"])

filtered_weather_df
# Out:
#        month  year   state  average_temp
# 38029      1  2016  Kansas          34.8
# 38077      2  2016  Kansas          36.4
# 38125      3  2016  Kansas          45.2
# 38173      4  2016  Kansas          53.0
# 38221      5  2016  Kansas          58.9
# ...      ...   ...     ...           ...
# 41245      8  2021  Kansas          78.4
# 41293      9  2021  Kansas          76.2
# 41341     10  2021  Kansas          66.2
# 41389     11  2021  Kansas          52.8
# 41437     12  2021  Kansas          43.9
#
# [72 rows x 4 columns]

# %%
#Code thats used for pretty much most of the bar charts.

monthly_mean_temps = filtered_weather_df.groupby("month")["average_temp"].mean()

year_to_plot = 2016
monthly_temps = filtered_weather_df.loc[filtered_weather_df["year"] == year_to_plot]

monthly_mean_temps = monthly_temps.groupby("month")["average_temp"].mean()

x_axis = monthly_mean_temps.index.values
y_axis = monthly_mean_temps.values

plt.bar(x_axis, y_axis, align="center", color="cyan")

plt.xlabel("Month")
plt.ylabel("Temperature (°F)")
plt.title(f"Monthly Mean Temperatures for {year_to_plot}")

tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"], rotation="vertical")
plt.show()

plt.show()

# %%
monthly_mean_temps = filtered_weather_df.groupby("month")["average_temp"].mean()

year_to_plot = 2017
monthly_temps = filtered_weather_df.loc[filtered_weather_df["year"] == year_to_plot]

monthly_mean_temps = monthly_temps.groupby("month")["average_temp"].mean()

x_axis = monthly_mean_temps.index.values
y_axis = monthly_mean_temps.values

plt.bar(x_axis, y_axis, align="center", color="b")

plt.xlabel("Month")
plt.ylabel("Temperature (°F)")
plt.title(f"Monthly Mean Temperatures for {year_to_plot}")

tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"], rotation="vertical")
plt.show()

plt.show()

# %%
monthly_mean_temps = filtered_weather_df.groupby("month")["average_temp"].mean()

year_to_plot = 2018
monthly_temps = filtered_weather_df.loc[filtered_weather_df["year"] == year_to_plot]

monthly_mean_temps = monthly_temps.groupby("month")["average_temp"].mean()

x_axis = monthly_mean_temps.index.values
y_axis = monthly_mean_temps.values

plt.bar(x_axis, y_axis, align="center", color="r")

plt.xlabel("Month")
plt.ylabel("Temperature (°F)")
plt.title(f"Monthly Mean Temperatures for {year_to_plot}")

tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"], rotation="vertical")
plt.show()

plt.show()

# %%
monthly_mean_temps = filtered_weather_df.groupby("month")["average_temp"].mean()

year_to_plot = 2019
yearly_temps = filtered_weather_df.loc[filtered_weather_df["year"] == year_to_plot]

yearly_mean_temps = yearly_temps.groupby("month")["average_temp"].mean()

x_axis = yearly_mean_temps.index.values
y_axis = yearly_mean_temps.values

plt.bar(x_axis, y_axis, align="center", color="g")

plt.xlabel("Month")
plt.ylabel("Temperature (°F)")
plt.title(f"Monthly Mean Temperatures for Kansas in {year_to_plot}")

tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"], rotation="vertical")
plt.show()

plt.show()

# %%
monthly_mean_temps = filtered_weather_df.groupby("month")["average_temp"].mean()

year_to_plot = 2020
monthly_temps = filtered_weather_df.loc[filtered_weather_df["year"] == year_to_plot]

monthly_mean_temps = monthly_temps.groupby("month")["average_temp"].mean()

x_axis = monthly_mean_temps.index.values
y_axis = monthly_mean_temps.values

plt.bar(x_axis, y_axis, align="center", color="orange")
# plt.plot(x_axis, y_axis, marker='^', color='red')
plt.xlabel("Month")
plt.ylabel("Temperature (°F)")
plt.title(f"Monthly Mean Temperatures for {year_to_plot}")

tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"], rotation="vertical")
plt.show()

plt.show()

# %%
monthly_mean_temps = filtered_weather_df.groupby("month")["average_temp"].mean()

year_to_plot = 2021
monthly_temps = filtered_weather_df.loc[filtered_weather_df["year"] == year_to_plot]

monthly_mean_temps = monthly_temps.groupby("month")["average_temp"].mean()

x_axis = monthly_mean_temps.index.values
y_axis = monthly_mean_temps.values

plt.bar(x_axis, y_axis, align="center", color="purple")
plt.plot(x_axis, y_axis, marker='^', color='red')

plt.xlabel("Month")
plt.ylabel("Temperature (°F)")
plt.title(f"Monthly Mean Temperatures for {year_to_plot}")

tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"], rotation="vertical")
plt.show()

plt.show()

# %%
#Getting the mean of all months between 2016-2022

monthly_mean_temps = filtered_weather_df.groupby("month")["average_temp"].mean()

year_to_plot = "2016 - 2021"
#monthly_temps = filtered_weather_df.loc[filtered_weather_df["year"] == year_to_plot]

#monthly_mean_temps = monthly_temps.groupby("month")["average_temp"].mean()

x_axis = monthly_mean_temps.index.values
y_axis = monthly_mean_temps.values


plt.bar(x_axis, y_axis, align="center", color="gold")

plt.xlabel("Month")
plt.ylabel("Temperature (°F)")
plt.title(f"Monthly Mean Temperatures for {year_to_plot}")

tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"], rotation="vertical")
plt.show()

plt.show()

# %%
# PT. 2 - Precipitaion Data

# %%
rain_data_df = pd.read_csv("weather_data/kansas_rain_data.csv")

rain_data_df
# Out:
#            Lat         Lon        Lon2   NORMALS 1981-2010 Unnamed: 4   Jan  \
# 0    39.633333  102.183333 -102.183333       BONNY DAM 2NE         CO  0.43
# 1    38.450000  102.450000 -102.450000             BRANDON         CO  0.25
# 2    39.316667  102.266667 -102.266667          BURLINGTON         CO  0.32
# 3    37.016667  102.566667 -102.566667           CAMPO 7 S         CO  0.35
# 4    38.816667  102.350000 -102.350000      CHEYENNE WELLS         CO  0.26
# ..         ...         ...         ...                 ...        ...   ...
# 358  36.666667   96.350000  -96.350000            PAWHUSKA         OK  1.68
# 359  36.733333   97.100000  -97.100000  PONCA CITY MUNI AP         OK  1.00
# 360  36.933333  102.633333 -102.633333             REGNIER         OK  0.35
# 361  36.666667   95.133333  -95.133333          VINITA 2 N         OK  1.98
# 362  36.583333   98.866667  -98.866667             WAYNOKA         OK  0.75
#
# ...

# %%
filtered_rain_df = rain_data_df

filtered_rain_df = rain_data_df.drop(columns=["Lat", "Lon", "Lon2"])

filtered_rain_df
# Out:
#       NORMALS 1981-2010 Unnamed: 4   Jan   Feb   Mar   Apr   May   Jun   Jul  \
# 0         BONNY DAM 2NE         CO  0.43  0.43  1.06  1.81  2.64  2.63  3.11
# 1               BRANDON         CO  0.25  0.22  0.65  1.48  2.13  2.74  2.67
# 2            BURLINGTON         CO  0.32  0.44  1.00  1.66  2.60  2.60  3.05
# 3             CAMPO 7 S         CO  0.35  0.38  1.00  1.33  2.10  2.46  2.69
# 4        CHEYENNE WELLS         CO  0.26  0.38  0.81  1.26  2.42  2.54  3.22
# ..                  ...        ...   ...   ...   ...   ...   ...   ...   ...
# 358            PAWHUSKA         OK  1.68  2.26  3.93  4.86  5.79  6.50  4.56
# 359  PONCA CITY MUNI AP         OK  1.00  1.34  2.71  3.44  4.81  5.06  3.33
# 360             REGNIER         OK  0.35  0.33  0.95  1.17  2.01  2.44  2.44
# 361          VINITA 2 N         OK  1.98  2.22  3.68  3.90  5.42  4.71  3.07
# 362             WAYNOKA         OK  0.75  1.01  2.16  2.17  4.31  4.28  2.69
#
#       Aug   Sep   Oct   Nov   Dec    ANN
# ...

# %%
month_rain_means =  [filtered_rain_df["Jan"].mean(),
            filtered_rain_df["Feb"].mean(),
            filtered_rain_df["Mar"].mean(),
            filtered_rain_df["Apr"].mean(),
            filtered_rain_df["May"].mean(),
            filtered_rain_df["Jun"].mean(),
            filtered_rain_df["Jul"].mean(),
            filtered_rain_df["Aug"].mean(),
            filtered_rain_df["Sep"].mean(),
            filtered_rain_df["Oct"].mean(),
            filtered_rain_df["Nov"].mean(),
            filtered_rain_df["Dec"].mean()
            ]

print(month_rain_means)
# Out:
# [0.7978512396694215, 1.0388980716253444, 2.1581542699724516, 2.772534435261708, 4.293636363636364, 4.285647382920111, 3.742561983471074, 3.3402479338842976, 2.789862258953168, 2.398154269972452, 1.5705234159779615, 1.1161707988980716]

# %%
x_axis1 = range(1, 13)

plt.plot(x_axis1, month_rain_means, marker='^', color='red')

plt.xlabel('Month')
plt.ylabel('Average Rainfall (inches)')
plt.title('Monthly Average Rainfall in Kansas')

months = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]
plt.xticks(x_axis1, months, rotation="vertical")

plt.show()

# %%
#average temp
x_axis = range(1, 13)
plt.plot(x_axis, monthly_mean_temps, marker='^', color='red', label='Temperature')

#average rainfall
plt.plot(x_axis, month_rain_means, marker='o', color='blue', label='Rainfall')

plt.xlabel("Month")
plt.ylabel("IDK")
plt.title(f"Monthly Mean Temperature and Rainfall for Kansas")
plt.legend()
plt.xticks(x_axis1, months, rotation="vertical")

months = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]

plt.show()
